# %%
import pandas as pd
import pylab as pl
import numpy as np
import seaborn as sns

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('../data/sdBShortP_training_set_ce_applied.csv')

# %%
df.describe()
# Out:
#          Unnamed: 0      FeH_init        Z_init      PRLODays  PoverPMax  \
# count  61358.000000  61358.000000  61358.000000  61358.000000    61358.0
# mean   30678.500000     -0.041595      0.013991    187.382537        1.0
# std    17712.673245      0.195040      0.004991    202.871440        0.0
# min        0.000000     -2.220758      0.000085      2.319832        1.0
# 25%    15339.250000     -0.112305      0.010964     33.029207        1.0
# 50%    30678.500000     -0.009464      0.013894    113.722770        1.0
# 75%    46017.750000      0.076004      0.016916    269.829257        1.0
# max    61357.000000      0.465943      0.041518    996.604398        1.0
#
#             TtipMyr     GalAgeMyr     AgeBinNum     DeltaTBin        P_init  \
# count  61358.000000  61358.000000  61358.000000  61358.000000  61358.000000
# mean    2614.884712   2379.904561      3.429968   1194.499495    187.382609
# std     2427.843260   2461.159984      1.717876    677.595642    202.871550
# ...

# %%
df_ce = df[df['stability'] == 'CE']

# %%
df_ce['product'].value_counts()
# Out:
# He-WD    11167
# sdB        756
# HB         174
# Name: product, dtype: int64

# %%
d = df_ce[['M1_init', 'q_init', 'P_init', 'FeH_init', 'alpha_ce', 'stability_limit', 'product']]
sns.pairplot(d, hue='product')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/Software/anaconda2/envs/py37/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     450     try:
# --> 451         bw = float(bw)
#     452     except:
#
# ValueError: could not convert string to float: 'scott'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-7-2957e93b3fa8> in <module>
#       1 d = df_ce[['M1_init', 'q_init', 'P_init', 'FeH_init', 'alpha_ce', 'stability_limit', 'product']]
# ----> 2 sns.pairplot(d, hue='product')
#
# ...
